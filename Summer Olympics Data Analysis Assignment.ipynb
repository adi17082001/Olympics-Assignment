# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = pd.read_csv("summer.csv")

# %% [markdown]
# ## 1. In how many cities Summer Olympics is held so far?

# %%
len(data['City'].unique())
# Out:
# 22

# %%
## Ans: 22

# %% [markdown]
# ## 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
## Ans: Football.
## The logic is implemented as below

# %%
sportsgold = data[data['Medal']=='Gold']

# %%
sportsgold
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
sportsgold['Event'].unique()
# Out:
# array(['100M Freestyle', '100M Freestyle For Sailors', '1200M Freestyle',
#        '400M Freestyle', '100M', '110M Hurdles', '1500M', '400M', '800M',
#        'Discus Throw', 'High Jump', 'Long Jump', 'Marathon', 'Pole Vault',
#        'Shot Put', 'Triple Jump', 'Individual Road Race', '100KM', '10KM',
#        '12-Hour Race', '1KM Time Trial', 'Sprint Indivual',
#        'Foil Individual', 'Foil, Masters', 'Sabre Individual',
#        'Horizontal Bar', 'Parallel Bars', 'Pommel Horse', 'Rings',
#        'Rope Climbing', 'Team, Horizontal Bar', 'Team, Parallel Bars',
#        'Vault', '25M Army Pistol', '25M Rapid Fire Pistol (60 Shots)',
#        '50M Pistol (60 Shots)', 'Army Rifle, 200M', 'Army Rifle, 300M',
#        'Doubles', 'Singles', 'Heavyweight - One Hand Lift',
#        'Heavyweight - Two Hand Lift', 'Open Event', '1500M Freestyle',
#        '200M Backstroke', '200M Freestyle', '200M Obstacle Event',
#        '200M Team Swimming', '4000M Freestyle', 'Underwater Swimming',
# ...

# %%
dbar = sportsgold.groupby('Event')['Medal'].count().sort_values(ascending=False).head(10)

# %%
dbar
# Out:
# Event
# Football                    503
# Hockey                      486
# Team Competition            403
# Basketball                  342
# Water Polo                  325
# Handball                    321
# Volleyball                  312
# Team                        312
# Eight With Coxswain (8+)    306
# 4X100M Relay                183
# Name: Medal, dtype: int64

# %%
labels = ['Football','Hockey','Team Competition','Basketball','Water Polo']
values = [503,486,403,342,325]

# %%
#Plotting the graph

plt.bar(labels,values,color = 'Blue',width = 0.2)
plt.xlabel("Event")
plt.ylabel("Number of golds")
plt.title("Events with most number of golds")
plt.show()

# %% [markdown]
# ## 3. Which sport is having most number of medals so far? (Top 5)

# %%
## Ans: Football

## the logic is implemented as below.

# %%
eventgold = data.groupby('Event')['Medal'].count().sort_values(ascending=False).head(10)

# %%
eventgold
# Out:
# Event
# Football                    1497
# Hockey                      1422
# Team Competition            1147
# Basketball                  1012
# Handball                     973
# Water Polo                   958
# Volleyball                   934
# Eight With Coxswain (8+)     918
# Team                         908
# 4X100M Relay                 533
# Name: Medal, dtype: int64

# %%
# Plotting the graph


labels = ['Football','Hockey','Team Competition','Basketball','Handball']
values = [1497,1422,1147,1012,973]

plt.bar(labels,values,color = 'Red',width = 0.3)
plt.xlabel("Events")
plt.ylabel("Number of medals")
plt.title("Events with most number of medals")
plt.show()

# %% [markdown]
# ## 4. Which player has won most number of medals? (Top 5)

# %%
## Ans: PHELPS, Michael
    #PHELPS, Michael         22
    #LATYNINA, Larisa        18
    #ANDRIANOV, Nikolay      15
    #MANGIAROTTI, Edoardo    13
    #ONO, Takashi            13

# %%
playermedal = data.groupby('Athlete')['Medal'].count().sort_values(ascending=False).head(10)

# %%
playermedal
# Out:
# Athlete
# PHELPS, Michael         22
# LATYNINA, Larisa        18
# ANDRIANOV, Nikolay      15
# MANGIAROTTI, Edoardo    13
# ONO, Takashi            13
# SHAKHLIN, Boris         13
# COUGHLIN, Natalie       12
# NEMOV, Alexei           12
# KATO, Sawao             12
# NURMI, Paavo            12
# Name: Medal, dtype: int64

# %%
labels = ['PHELPS, Michael','LATYNINA, Larisa','ANDRIANOV, Nikolay','MANGIAROTTI, Edoardo','ONO, Takashi','SHAKHLIN, Boris','COUGHLIN, Natalie',
        'NEMOV, Alexei','KATO, Sawao','NURMI, Paavo']
values = [22,18,15,13,13,13,12,12,12,12]

#Plotting the graph
plt.figure(figsize = (20,7))
plt.bar(labels,values,color='Green',width=0.2)

plt.xlabel("Athlete")
plt.ylabel("Number of medals")
plt.title("Athletes with most number of medals")
plt.show()

# %% [markdown]
# ## 5. Which player has won most number of Gold  medals? (Top 5)

# %%
## Ans: PHELPS, Michael
#    PHELPS, Michael     18
#    LEWIS, Carl          9
#    NURMI, Paavo         9
#    SPITZ, Mark          9
#    LATYNINA, Larisa     9

#Logic is implemented as follows.

# %%
playergold = data[data['Medal']=='Gold']

# %%
playergold
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# 13     1896  Athens  Athletics            Athletics
# ...     ...     ...        ...                  ...
# 31145  2012  London  Wrestling  Wrestling Freestyle
# 31149  2012  London  Wrestling  Wrestling Freestyle
# 31153  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 3             MALOKINIS, Ioannis     GRE    Men  100M Freestyle For Sailors
# 6                  HAJOS, Alfred     HUN    Men             1200M Freestyle
# ...

# %%
mostgolds = playergold.groupby('Athlete')['Medal'].count().sort_values(ascending=False).head(5)

# %%
mostgolds
# Out:
# Athlete
# PHELPS, Michael     18
# LEWIS, Carl          9
# NURMI, Paavo         9
# SPITZ, Mark          9
# LATYNINA, Larisa     9
# Name: Medal, dtype: int64

# %%
labels = ['PHELPS, Michael','LEWIS, Carl','NURMI, Paavo','SPITZ, Mark','LATYNINA, Larisa']
values = [18,9,9,9,9]
plt.figure(figsize = (11,7))
plt.bar(labels,values,color = 'Green',width = 0.2)
plt.xlabel("Athletes")
plt.ylabel("Number of golds")
plt.title("Athletes with most number of golds")
plt.show()

# %% [markdown]
# ## 6. In which year India won first Gold Medal in Summer Olympics?

# %%
## Ans: 1928

# the logic and code is implemented as follows..

# %%
Indiamedal = data[data['Country']=='IND']

# %%
Indiamedal
# Out:
#        Year       City      Sport           Discipline               Athlete  \
# 241    1900      Paris  Athletics            Athletics     PRITCHARD, Norman
# 244    1900      Paris  Athletics            Athletics     PRITCHARD, Norman
# 5512   1928  Amsterdam     Hockey               Hockey  ALLEN, Richard James
# 5513   1928  Amsterdam     Hockey               Hockey           CHAND, Dyan
# 5514   1928  Amsterdam     Hockey               Hockey   GATELEY, Maurice A.
# ...     ...        ...        ...                  ...                   ...
# 29879  2012     London     Boxing               Boxing             KOM, Mary
# 30841  2012     London   Shooting             Shooting         NARANG, Gagan
# 30849  2012     London   Shooting             Shooting          KUMAR, Vijay
# 31111  2012     London  Wrestling  Wrestling Freestyle       DUTT, Yogeshwar
# 31118  2012     London  Wrestling  Wrestling Freestyle         KUMAR, Sushil
#
# ...

# %%
Indiafirstgold = Indiamedal[Indiamedal['Medal']=='Gold']

# %%
Indiafirstgold
# Out:
#        Year       City     Sport Discipline                       Athlete  \
# 5512   1928  Amsterdam    Hockey     Hockey          ALLEN, Richard James
# 5513   1928  Amsterdam    Hockey     Hockey                   CHAND, Dyan
# 5514   1928  Amsterdam    Hockey     Hockey           GATELEY, Maurice A.
# 5515   1928  Amsterdam    Hockey     Hockey                   GILL, K. S.
# 5516   1928  Amsterdam    Hockey     Hockey  GOODSIR-CULLEN, William John
# ...     ...        ...       ...        ...                           ...
# 16099  1980     Moscow    Hockey     Hockey                  SINGH, Singh
# 16100  1980     Moscow    Hockey     Hockey               SURINDER, Singh
# 16101  1980     Moscow    Hockey     Hockey           SYLVANUS, Dung Dung
# 16102  1980     Moscow    Hockey     Hockey                  ZAFAR, Zafar
# 28856  2008    Beijing  Shooting   Shooting               BINDRA, Abhinav
#
#       Country Gender                     Event Medal
# ...

# %%
Indiafirstgold['Year'].head(1)
# Out:
# 5512    1928
# Name: Year, dtype: int64

# %% [markdown]
# ## 7. Which event is most popular in terms on number of players? (Top 5)

# %%
## Ans: Football
#      the most popular event maybe the one with the most number of medals.
# the logic implemented is as follows...

# %%
popularevent = data.groupby('Event')['Athlete'].count().sort_values(ascending = False).head(5)

# %%
popularevent
# Out:
# Event
# Football            1497
# Hockey              1422
# Team Competition    1147
# Basketball          1012
# Handball             973
# Name: Athlete, dtype: int64

# %%
labels = ['Football','Hockey','Team Competition','Basketball','Handball']
values = [1497,1422,1147,1012,973]
plt.figure(figsize = (15,7))
plt.bar(labels,values,color = 'Blue',width=0.3)
plt.xlabel('Event')
plt.ylabel('Number of medals won by players')
plt.title('Most popular event')
plt.show()

# %% [markdown]
# ## 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
## Ans: Volleyball
## the logic and code has been implemented as follows:

# %%
femalesports = data[data['Gender']=='Women']

# %%
femalesports
# Out:
#        Year    City      Sport           Discipline                   Athlete  \
# 416    1900   Paris       Golf                 Golf              PRATT, Daria
# 417    1900   Paris       Golf                 Golf     ABBOTT, Margaret Ives
# 418    1900   Paris       Golf                 Golf         WHITTIER, Pauline
# 639    1900   Paris     Tennis               Tennis             JONES, Marion
# 640    1900   Paris     Tennis               Tennis         ROSENBAUM, Hedwig
# ...     ...     ...        ...                  ...                       ...
# 31116  2012  London  Wrestling  Wrestling Freestyle           VOLOSOVA, Lubov
# 31121  2012  London  Wrestling  Wrestling Freestyle        VOROBIEVA, Natalia
# 31122  2012  London  Wrestling  Wrestling Freestyle  HRISTOVA, Stanka Zlateva
# 31123  2012  London  Wrestling  Wrestling Freestyle          MANYUROVA, Guzel
# 31124  2012  London  Wrestling  Wrestling Freestyle              UNDA, Maider
#
# ...

# %%
femalegold = femalesports[femalesports['Medal']=='Gold']

# %%
femalegold
# Out:
#        Year      City          Sport           Discipline  \
# 417    1900     Paris           Golf                 Golf
# 641    1900     Paris         Tennis               Tennis
# 649    1900     Paris         Tennis               Tennis
# 710    1904  St Louis        Archery              Archery
# 713    1904  St Louis        Archery              Archery
# ...     ...       ...            ...                  ...
# 31081  2012    London  Weightlifting        Weightlifting
# 31097  2012    London      Wrestling  Wrestling Freestyle
# 31105  2012    London      Wrestling  Wrestling Freestyle
# 31113  2012    London      Wrestling  Wrestling Freestyle
# 31121  2012    London      Wrestling  Wrestling Freestyle
#
#                      Athlete Country Gender  \
# 417    ABBOTT, Margaret Ives     USA  Women
# 641        COOPER, Charlotte     GBR  Women
# 649        COOPER, Charlotte     GBR  Women
# 710    HOWELL, Matilda Scott     USA  Women
# ...

# %%
mostfemalegolds = femalegold.groupby('Event')['Medal'].count().sort_values(ascending = False).head(10)

# %%
mostfemalegolds
# Out:
# Event
# Volleyball                  156
# Hockey                      144
# Handball                    142
# Team Competition            126
# Basketball                  120
# 4X100M Freestyle Relay       99
# Team                         94
# Football                     86
# 4X100M Relay                 86
# Eight With Coxswain (8+)     81
# Name: Medal, dtype: int64

# %%
mostfemalegolds.keys()
# Out:
# Index(['Volleyball', 'Hockey', 'Handball', 'Team Competition', 'Basketball',
#        '4X100M Freestyle Relay', 'Team', 'Football', '4X100M Relay',
#        'Eight With Coxswain (8+)'],
#       dtype='object', name='Event')

# %%
labels = ['Volleyball', 'Hockey', 'Handball', 'Team Competition', 'Basketball',
       '4X100M Freestyle Relay', 'Team', 'Football', '4X100M Relay',
       'Eight With Coxswain (8+)']
values = [156,144,142,126,120,99,94,86,86,81]

# Plotting the graph.....
plt.figure(figsize=(20,7))
plt.bar(labels,values,color = 'Red',width = 0.2)
plt.xlabel('Event')
plt.ylabel('Number of golds')
plt.title("Event with most number of female gold medalists")
plt.show()
